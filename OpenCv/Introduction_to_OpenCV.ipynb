# %%
import cv2 as cv
from IPython.display import Image
import matplotlib.pyplot as plt

# %%
img=cv.imread("coca-cola.png",1)

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (224, 224, 3)

# %%
h,w=img.shape[:2]

# %%
print("Height = {} , Width= {}".format(h,w))
# Out:
# Height = 224 , Width= 224

# %%
cv.imshow('img',img)
cv.waitKey(0)
cv.destroyAllWindows()
